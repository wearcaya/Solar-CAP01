# %% [markdown]
# # Solar-CAP CLEI 2026 reproducibility notebook
#
# Run the cell below to regenerate all results, figures, and LaTeX tables.

# %%
# !python ../src/run_experiments.py

# %% [markdown]
# The generated CSV files are stored in `../results/csv`, figures in `../results/figures`, and LaTeX tables in `../results/tables`.
